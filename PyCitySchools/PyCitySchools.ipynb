# %% [markdown]
# ## Option 2: Academy of Py
#
# ![Education](../Images/education.jpg)
#
# Well done! Having spent years analyzing financial records for big banks, you've finally scratched your idealistic itch and joined the education sector. In your latest role, you've become the Chief Data Scientist for your city's school district. In this capacity, you'll be helping the  school board and mayor make strategic decisions regarding future school budgets and priorities.
#
# As a first task, you've been asked to analyze the district-wide standardized test results. You'll be given access to every student's math and reading scores, as well as various information on the schools they attend. Your responsibility is to aggregate the data to and showcase obvious trends in school performance.
#
# Your final report should include each of the following:
#
# **District Summary**
#
# * Create a high level snapshot (in table form) of the district's key metrics, including:
#   * Total Schools
#   * Total Students
#   * Total Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# **School Summary**
#
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per School Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# **Top Performing Schools (By Passing Rate)**
#
# * Create a table that highlights the top 5 performing schools based on Overall Passing Rate. Include:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per School Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# **Top Performing Schools (By Passing Rate)**
#
# * Create a table that highlights the bottom 5 performing schools based on Overall Passing Rate. Include all of the same metrics as above.
#
# **Math Scores by Grade**
#
# * Create a table that lists the average Math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
# **Reading Scores by Grade**
#
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
# **Scores by School Spending**
#
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# **Scores by School Size**
#
# * Repeat the above breakdown, but this time group schools based on a reasonable approximation of school size (Small, Medium, Large).
#
# **Scores by School Type**
#
# * Repeat the above breakdown, but this time group schools based on school type (Charter vs. District).
#
# As final considerations:
#
# * Your script must work for both data-sets given.
# * You must use the Pandas Library and the Jupyter Notebook.
# * You must submit a link to your Jupyter Notebook with the viewable Data Frames.
# * You must include an exported markdown version of your Notebook called  `README.md` in your GitHub repository.
# * You must include a written description of three observable trends based on the data.
# * See [Example Solution](PyCitySchools_Example.pdf) for a reference on the expected format.
#
# ## Hints and Considerations
#
# * These are challenging activities for a number of reasons. For one, these activities will require you to analyze thousands of records. Hacking through the data to look for obvious trends in Excel is just not a feasible option. The size of the data may seem daunting, but Python Pandas will allow you to efficiently parse through it.
#
# * Second, these activities will also challenge you by requiring you to learn on your feet. Don't fool yourself into thinking: "I need to study Pandas more closely before diving in." Get the basic gist of the library and then _immediately_ get to work. When facing a daunting task, it's easy to think: "I'm just not ready to tackle it yet." But that's the surest way to never succeed. Learning to program requires one to constantly tinker, experiment, and learn on the fly. You are doing exactly the _right_ thing, if you find yourself constantly practicing Google-Fu and diving into documentation. There is just no way (or reason) to try and memorize it all. Online references are available for you to use when you need them. So use them!
#
# * Take each of these tasks one at a time. Begin your work, answering the basic questions: "How do I import the data?" "How do I convert the data into a DataFrame?" "How do I build the first table?" Don't get intimidated by the number of asks. Many of them are repetitive in nature with just a few tweaks. Be persistent and creative!
#
# * Expect these exercises to take time! Don't get discouraged if you find yourself spending  hours initially with little progress. Force yourself to deal with the discomfort of not knowing and forge ahead. This exercise is likely to take between 15-30 hours of your time. Consider these hours an investment in your future!
#
# * As always, feel encouraged to work in groups and get help from your TAs and Instructor. Just remember, true success comes from mastery and _not_ a completed homework assignment. So challenge yourself to truly succeed!
#
# ## Copyright

# %%
# import dependencies
import pandas as pd
import numpy as np
import os 
import csv

# %%
# file path to the inputs
filepath_schools = os.path.join("raw_data","schools_complete.csv")
filepath_students = os.path.join("raw_data","students_complete.csv")

# %%
# read-in the inputs using pandas
df_schools = pd.read_csv(filepath_schools,sep=',')
df_students = pd.read_csv(filepath_students,sep=',')

# %%
# print the head of the dataframes
display(df_schools.head())
display(df_students.head())
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# print the shape of the dataframes
display(df_schools.shape)
display(df_students.shape)
# Out:
# (15, 5)
# (39170, 7)

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **District Summary**
#
# * Create a high level snapshot (in table form) of the district's key metrics, including:
#   * Total Schools
#   * Total Students
#   * Total Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#from school df
summary_district1 = pd.DataFrame({ "Total Schools" : df_schools['School ID'].nunique(),
"Total Students" : df_schools['size'].sum(),
"Total Budget" : df_schools['budget'].sum()},index=[0])
summary_district1.style.set_properties(**{'background-color': 'ash',
                           'color': 'blue',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_742318fa_c0e0_11e7_8f50_186590d6f757row0_col0 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742318fa_c0e0_11e7_8f50_186590d6f757row0_col1 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742318fa_c0e0_11e7_8f50_186590d6f757row0_col2 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }</style>
# <table id="T_742318fa_c0e0_11e7_8f50_186590d6f757" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total Budget</th>
#         <th class="col_heading level0 col1" >Total Schools</th>
#         <th class="col_heading level0 col2" >Total Students</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_742318fa_c0e0_11e7_8f50_186590d6f757" class="row_heading level0 row0" >0</th>
# ...

# %%
# #from student df
summary_district2 = pd.DataFrame({"Average Math Score" : df_students['math_score'].mean(),
"Average Reading Score" : df_students['reading_score'].mean(),
"% Passing Math": (df_students['math_score'].apply(lambda x: x >= 75)).mean(),
"% Passing Reading": (df_students['reading_score'].apply(lambda x: x >= 75)).mean()},index=[0])
                                  
summary_district2["Overall Passing Rate"] = (summary_district2["% Passing Math"]+ \
                                            summary_district2["% Passing Reading"] )/2
    
summary_district2.style.set_properties(**{'background-color': 'ash',
                           'color': 'blue',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_742c8862_c0e0_11e7_b3af_186590d6f757row0_col0 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742c8862_c0e0_11e7_b3af_186590d6f757row0_col1 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742c8862_c0e0_11e7_b3af_186590d6f757row0_col2 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742c8862_c0e0_11e7_b3af_186590d6f757row0_col3 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742c8862_c0e0_11e7_b3af_186590d6f757row0_col4 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }</style>
# <table id="T_742c8862_c0e0_11e7_b3af_186590d6f757" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
# ...

# %%
district_summary = pd.concat([summary_district1, summary_district2], axis=1)
district_summary.style.set_properties(**{'background-color': 'ash',
                           'color': 'blue',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_742f9f50_c0e0_11e7_aafc_186590d6f757row0_col0 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742f9f50_c0e0_11e7_aafc_186590d6f757row0_col1 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742f9f50_c0e0_11e7_aafc_186590d6f757row0_col2 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742f9f50_c0e0_11e7_aafc_186590d6f757row0_col3 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742f9f50_c0e0_11e7_aafc_186590d6f757row0_col4 {
#             background-color:  ash;
#             color:  blue;
#             border-color:  white;
#         }    #T_742f9f50_c0e0_11e7_aafc_186590d6f757row0_col5 {
#             background-color:  ash;
#             color:  blue;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **School Summary**
#
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per School Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
summary_school1 = df_schools.groupby(["name","type"]).agg({"size":np.sum,"budget":np.sum}).reset_index()
summary_school1.columns = ["School Name","School Type","Total Students", "Total School Budget"]
summary_school1["Per School Budget"] = summary_school1["Total School Budget"]/summary_school1["Total Students"]
summary_school1 = summary_school1.set_index("School Name")
summary_school1
# Out:
#                       School Type  Total Students  Total School Budget  \
# School Name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
summary_school2 = df_students.groupby(["school"]).agg({'math_score':np.mean,'reading_score':np.mean}).reset_index()
summary_school2 = summary_school2.set_index("school")
summary_school2
# Out:
#                        math_score  reading_score
# school
# Bailey High School      77.048432      81.033963
# Cabrera High School     83.061895      83.975780
# Figueroa High School    76.711767      81.158020
# Ford High School        77.102592      80.746258
# Griffin High School     83.351499      83.816757
# Hernandez High School   77.289752      80.934412
# Holden High School      83.803279      83.814988
# Huang High School       76.629414      81.182722
# Johnson High School     77.072464      80.966394
# Pena High School        83.839917      84.044699
# Rodriguez High School   76.842711      80.744686
# Shelton High School     83.359455      83.725724
# Thomas High School      83.418349      83.848930
# Wilson High School      83.274201      83.989488
# Wright High School      83.682222      83.955000

# %%
def passrate(x):
    return (x['math_score'].apply(lambda x: x >= 75).mean(),
            x['reading_score'].apply(lambda x: x >= 75).mean())

summary_school3 = df_students.groupby('school').apply(passrate).reset_index()
summary_school3[['% Passing Math', '% Passing Reading']] = summary_school3[0].apply(pd.Series)
summary_school3 = summary_school3.set_index("school")
summary_school3 = summary_school3[['% Passing Math', '% Passing Reading']]
summary_school3
# Out:
#                        % Passing Math  % Passing Reading
# school
# Bailey High School           0.558481           0.691117
# Cabrera High School          0.760495           0.801399
# Figueroa High School         0.540522           0.687352
# Ford High School             0.566265           0.667032
# Griffin High School          0.781335           0.791553
# Hernandez High School        0.561165           0.670766
# Holden High School           0.789227           0.786885
# Huang High School            0.539595           0.686322
# Johnson High School          0.548414           0.679059
# Pena High School             0.776507           0.811850
# Rodriguez High School        0.550138           0.669667
# Shelton High School          0.787053           0.793299
# Thomas High School           0.782263           0.790214
# Wilson High School           0.776172           0.809899
# Wright High School           0.793889           0.815556

# %%
summary_school = pd.concat([summary_school1,summary_school2,summary_school3],axis=1)
summary_school['Overall Passing Rate']= (summary_school['% Passing Math']+summary_school['% Passing Reading'])/2
summary_school.style.set_properties(**{'background-color': '#324376',
                           'color': 'white',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_744d743a_c0e0_11e7_b424_186590d6f757row0_col0 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_744d743a_c0e0_11e7_b424_186590d6f757row0_col1 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_744d743a_c0e0_11e7_b424_186590d6f757row0_col2 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_744d743a_c0e0_11e7_b424_186590d6f757row0_col3 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_744d743a_c0e0_11e7_b424_186590d6f757row0_col4 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_744d743a_c0e0_11e7_b424_186590d6f757row0_col5 {
#             background-color:  #324376;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Top Performing Schools (By Passing Rate)**
#
# * Create a table that highlights the top 5 performing schools based on Overall Passing Rate. Include:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per School Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
summary_school.sort_values('Overall Passing Rate',ascending=False)[:5].style.set_properties(**{'background-color': '#324376',
                           'color': 'white',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_7451f7ee_c0e0_11e7_a8ff_186590d6f757row0_col0 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_7451f7ee_c0e0_11e7_a8ff_186590d6f757row0_col1 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_7451f7ee_c0e0_11e7_a8ff_186590d6f757row0_col2 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_7451f7ee_c0e0_11e7_a8ff_186590d6f757row0_col3 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_7451f7ee_c0e0_11e7_a8ff_186590d6f757row0_col4 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_7451f7ee_c0e0_11e7_a8ff_186590d6f757row0_col5 {
#             background-color:  #324376;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Top Performing Schools (By Passing Rate)**
#
# * Create a table that highlights the bottom 5 performing schools based on Overall Passing Rate. Include all of the same metrics as above.

# %%
summary_school.sort_values('Overall Passing Rate',ascending=False)[-5:].style.set_properties(**{'background-color': '#324376',
                           'color': 'white',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_74559a7a_c0e0_11e7_98c0_186590d6f757row0_col0 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_74559a7a_c0e0_11e7_98c0_186590d6f757row0_col1 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_74559a7a_c0e0_11e7_98c0_186590d6f757row0_col2 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_74559a7a_c0e0_11e7_98c0_186590d6f757row0_col3 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_74559a7a_c0e0_11e7_98c0_186590d6f757row0_col4 {
#             background-color:  #324376;
#             color:  white;
#             border-color:  white;
#         }    #T_74559a7a_c0e0_11e7_98c0_186590d6f757row0_col5 {
#             background-color:  #324376;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Math Scores by Grade**
#
# * Create a table that lists the average Math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

# %%
summary_math = df_students.groupby(['school','grade']).agg({"math_score":np.mean}).unstack()

# %%
summary_math.style.bar(color='#05668D')
# Out:
# <style  type="text/css" >
#     #T_746a3b58_c0e0_11e7_944f_186590d6f757row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 13.1%, transparent 0%);
#         }    #T_746a3b58_c0e0_11e7_944f_186590d6f757row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 13.0%, transparent 0%);
#         }    #T_746a3b58_c0e0_11e7_944f_186590d6f757row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 3.9%, transparent 0%);
#         }    #T_746a3b58_c0e0_11e7_944f_186590d6f757row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 9.2%, transparent 0%);
#         }    #T_746a3b58_c0e0_11e7_944f_186590d6f757row1_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Reading Scores by Grade**
#
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

# %%
summary_reading = df_students.groupby(['school','grade']).agg({"reading_score":np.mean}).unstack()

# %%
summary_reading.style.bar(color='#05668D')
# Out:
# <style  type="text/css" >
#     #T_7478dc9c_c0e0_11e7_ae5c_186590d6f757row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 7.7%, transparent 0%);
#         }    #T_7478dc9c_c0e0_11e7_ae5c_186590d6f757row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 13.7%, transparent 0%);
#         }    #T_7478dc9c_c0e0_11e7_ae5c_186590d6f757row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 13.8%, transparent 0%);
#         }    #T_7478dc9c_c0e0_11e7_ae5c_186590d6f757row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 19.2%, transparent 0%);
#         }    #T_7478dc9c_c0e0_11e7_ae5c_186590d6f757row1_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Scores by School Spending**
#
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
df_students_new = df_students.merge(df_schools,left_on='school',right_on='name')
df_students_new['Per Student Budget']=df_students_new['budget']/df_students_new['size']

# %%
df_students_new.head()
# Out:
#    Student ID             name_x gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID             name_y      type  size  \
# 0             66          79          0  Huang High School  District  2917
# 1             94          61          0  Huang High School  District  2917
# 2             90          60          0  Huang High School  District  2917
# 3             67          58          0  Huang High School  District  2917
# 4             97          84          0  Huang High School  District  2917
#
#     budget  Per Student Budget
# 0  1910635               655.0
# 1  1910635               655.0
# ...

# %%
import matplotlib.pyplot as plt
df_students_new['Per Student Budget'].plot(kind='hist')
plt.show()

# %%
perstudent_bins = [0,600,650,700]
perstudent_labels = ['<600', '600-650', '650+']
df_students_new['Per Student Budget Category'] = pd.cut(df_students_new['Per Student Budget'], perstudent_bins ,labels = perstudent_labels ,right=False)

# %%
summary_scores1 = df_students_new.groupby(['Per Student Budget Category']).agg({'math_score':np.mean,'reading_score':np.mean})
summary_scores1
# Out:
#                              math_score  reading_score
# Per Student Budget Category
# <600                          83.363065      83.964039
# 600-650                       78.788277      81.753624
# 650+                          77.049297      81.005604

# %%
def passrate(x):
    return (x['math_score'].apply(lambda x: x >= 75).mean(),
            x['reading_score'].apply(lambda x: x >= 75).mean())

summary_scores2 = df_students_new.groupby(['Per Student Budget Category']).apply(passrate).reset_index()
summary_scores2[['% Passing Math', '% Passing Reading']] = summary_scores2[0].apply(pd.Series)
summary_scores2 = summary_scores2.set_index("Per Student Budget Category")
summary_scores2 = summary_scores2[['% Passing Math', '% Passing Reading']]
summary_scores2
# Out:
#                              % Passing Math  % Passing Reading
# Per Student Budget Category
# <600                               0.777481           0.807475
# 600-650                            0.619015           0.712724
# 650+                               0.551125           0.677658

# %%
summary_scores = pd.concat([summary_scores1,summary_scores2],axis=1)
summary_scores ['Overall Passing Rate']= (summary_scores['% Passing Math']+summary_scores['% Passing Reading'])/2
summary_scores.style.bar(color='#05668D')
# Out:
# <style  type="text/css" >
#     #T_74e85f36_c0e0_11e7_b4aa_186590d6f757row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_74e85f36_c0e0_11e7_b4aa_186590d6f757row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_74e85f36_c0e0_11e7_b4aa_186590d6f757row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_74e85f36_c0e0_11e7_b4aa_186590d6f757row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_74e85f36_c0e0_11e7_b4aa_186590d6f757row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Scores by School Size**
#
# * Repeat the above breakdown, but this time group schools based on a reasonable approximation of school size (Small, Medium, Large).

# %%
df_students_new.head()
# Out:
#    Student ID             name_x gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID             name_y      type  size  \
# 0             66          79          0  Huang High School  District  2917
# 1             94          61          0  Huang High School  District  2917
# 2             90          60          0  Huang High School  District  2917
# 3             67          58          0  Huang High School  District  2917
# 4             97          84          0  Huang High School  District  2917
#
#     budget  Per Student Budget Per Student Budget Category
# 0  1910635               655.0                        650+
# ...

# %%
import matplotlib.pyplot as plt
df_students_new['size'].plot(kind='hist')
plt.show()

# %%
size_bins = [0,1500,3000,6000]
size_labels = ['Small(<1500)', 'Medium(1500-3000)', 'Large(3000+)']
df_students_new['School Size Category'] = pd.cut(df_students_new['size'], size_bins ,labels = size_labels ,right=False)

# %%
summary_size1 = df_students_new.groupby(['School Size Category']).agg({'math_score':np.mean,'reading_score':np.mean})
summary_size1
# Out:
#                       math_score  reading_score
# School Size Category
# Small(<1500)           83.583479      83.893245
# Medium(1500-3000)      80.213577      82.529094
# Large(3000+)           77.070764      80.928365

# %%
def passrate(x):
    return (x['math_score'].apply(lambda x: x >= 75).mean(),
            x['reading_score'].apply(lambda x: x >= 75).mean())

summary_size2 = df_students_new.groupby(['School Size Category']).apply(passrate).reset_index()
summary_size2[['% Passing Math', '% Passing Reading']] = summary_size2[0].apply(pd.Series)
summary_size2 = summary_size2.set_index("School Size Category")
summary_size2 = summary_size2[['% Passing Math', '% Passing Reading']]
summary_size2
# Out:
#                       % Passing Math  % Passing Reading
# School Size Category
# Small(<1500)                0.780889           0.797690
# Medium(1500-3000)           0.668710           0.744120
# Large(3000+)                0.554733           0.678188

# %%
summary_size = pd.concat([summary_size1,summary_size2],axis=1)
summary_size ['Overall Passing Rate']= (summary_size['% Passing Math']+summary_size['% Passing Reading'])/2
summary_size.style.bar(color='#05668D')
# Out:
# <style  type="text/css" >
#     #T_75548f94_c0e0_11e7_a913_186590d6f757row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75548f94_c0e0_11e7_a913_186590d6f757row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75548f94_c0e0_11e7_a913_186590d6f757row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75548f94_c0e0_11e7_a913_186590d6f757row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75548f94_c0e0_11e7_a913_186590d6f757row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # ------------------------------------------------------------------------------------------

# %% [markdown]
# **Scores by School Type**
#
# * Repeat the above breakdown, but this time group schools based on school type (Charter vs. District).

# %%
summary_type1 = df_students_new.groupby(['type']).agg({'math_score':np.mean,'reading_score':np.mean})
summary_type1
# Out:
#           math_score  reading_score
# type
# Charter    83.406183      83.902821
# District   76.987026      80.962485

# %%
def passrate(x):
    return (x['math_score'].apply(lambda x: x >= 75).mean(),
            x['reading_score'].apply(lambda x: x >= 75).mean())

summary_type2 = df_students_new.groupby(['type']).apply(passrate).reset_index()
summary_type2[['% Passing Math', '% Passing Reading']] = summary_type2[0].apply(pd.Series)
summary_type2 = summary_type2.set_index("type")
summary_type2 = summary_type2[['% Passing Math', '% Passing Reading']]
summary_type2
# Out:
#           % Passing Math  % Passing Reading
# type
# Charter         0.779892           0.801542
# District        0.552714           0.678937

# %%
summary_type = pd.concat([summary_type1,summary_type2],axis=1)
summary_type ['Overall Passing Rate']= (summary_type['% Passing Math']+summary_type['% Passing Reading'])/2
summary_type.style.bar(color='#05668D')
# Out:
# <style  type="text/css" >
#     #T_75636438_c0e0_11e7_be64_186590d6f757row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75636438_c0e0_11e7_be64_186590d6f757row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75636438_c0e0_11e7_be64_186590d6f757row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75636438_c0e0_11e7_be64_186590d6f757row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#05668D 100.0%, transparent 0%);
#         }    #T_75636438_c0e0_11e7_be64_186590d6f757row0_col4 {
#             width:  10em;
#              height:  80%;
# ...
